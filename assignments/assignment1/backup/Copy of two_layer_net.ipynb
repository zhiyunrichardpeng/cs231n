# %%
# Install Python 3.11
! apt-get update -y
! apt-get install python3.11 python3.11-distutils -y
! update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 1

# Install the Jupyter kernel package for Python 3.11
! python3.11 -m pip install ipykernel
! python3.11 -m ipykernel install --user --name=python311 --display-name "Python 3.11 (Fixed)"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,297 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,868 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,607 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:22 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:24 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [44.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Fetched 38.7 MB in 9s (4,275 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.11-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# The following additional packages will be installed:
#   libpython3.11 libpython3.11-dev libpython3.11-minimal libpython3.11-stdlib
#   python3.11-dev python3.11-minimal
# Suggested packages:
#   python3.11-venv binfmt-support
# The following packages will be upgraded:
#   libpython3.11 libpython3.11-dev libpython3.11-minimal libpython3.11-stdlib
#   python3.11 python3.11-dev python3.11-minimal
# 7 upgraded, 0 newly installed, 0 to remove and 217 not upgraded.
# Need to get 13.3 MB of archives.
# After this operation, 7,168 B of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.11-dev amd64 3.11.14-1+jammy1 [500 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11-dev amd64 3.11.14-1+jammy1 [5,323 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11 amd64 3.11.14-1+jammy1 [2,221 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.11 amd64 3.11.14-1+jammy1 [94.3 kB]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11-stdlib amd64 3.11.14-1+jammy1 [1,927 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.11-minimal amd64 3.11.14-1+jammy1 [2,358 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.11-minimal amd64 3.11.14-1+jammy1 [887 kB]
# Fetched 13.3 MB in 45s (299 kB/s)
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../0-python3.11-dev_3.11.14-1+jammy1_amd64.deb ...
# Unpacking python3.11-dev (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../1-libpython3.11-dev_3.11.14-1+jammy1_amd64.deb ...
# Unpacking libpython3.11-dev:amd64 (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../2-libpython3.11_3.11.14-1+jammy1_amd64.deb ...
# Unpacking libpython3.11:amd64 (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../3-python3.11_3.11.14-1+jammy1_amd64.deb ...
# Unpacking python3.11 (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../4-libpython3.11-stdlib_3.11.14-1+jammy1_amd64.deb ...
# Unpacking libpython3.11-stdlib:amd64 (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../5-python3.11-minimal_3.11.14-1+jammy1_amd64.deb ...
# Unpacking python3.11-minimal (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Preparing to unpack .../6-libpython3.11-minimal_3.11.14-1+jammy1_amd64.deb ...
# Unpacking libpython3.11-minimal:amd64 (3.11.14-1+jammy1) over (3.11.13-1+jammy1) ...
# Setting up libpython3.11-minimal:amd64 (3.11.14-1+jammy1) ...
# Setting up python3.11-minimal (3.11.14-1+jammy1) ...
# Setting up libpython3.11-stdlib:amd64 (3.11.14-1+jammy1) ...
# Setting up python3.11 (3.11.14-1+jammy1) ...
# Setting up libpython3.11:amd64 (3.11.14-1+jammy1) ...
# Setting up libpython3.11-dev:amd64 (3.11.14-1+jammy1) ...
# Setting up python3.11-dev (3.11.14-1+jammy1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (6.17.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel) (5.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.7 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installed kernelspec python311 in /root/.local/share/jupyter/kernels/python311

# %%
import sys
import IPython

print(f"Python version: {sys.version}")
print(f"IPython version: {IPython.__version__}")

try:
    import imp
    print("imp module: FOUND")
except ImportError:
    print("imp module: MISSING (This causes the crash)")
# Out:
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# IPython version: 7.34.0
# imp module: FOUND

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Fully-Connected Neural Nets
# In this exercise we will implement fully-connected networks using a modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Affine layer: forward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

from cs231n.layers import affine_forward

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function
from cs231n.layers import affine_backward
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # ReLU activation: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function
from cs231n.layers import relu_forward
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # ReLU activation: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
from cs231n.layers import relu_backward
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Inline Question 1:
#
# We've only asked you to implement ReLU, but there are a number of different activation functions that one could use in neural networks, each with its pros and cons. In particular, an issue commonly seen with activation functions is getting zero (or close to zero) gradient flow during backpropagation. Which of the following activation functions have this problem? If you consider these functions in the one dimensional case, what types of input would lead to this behaviour?
# 1. Sigmoid
# 2. ReLU
# 3. Leaky ReLU
#
# $\color{blue}{\textit Your Answer:}$ *ReLu, Leaky ReLU, because not differentiable at the turning point.*

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# # Loss layers: Softmax
# Now implement the loss and gradient for softmax in the `softmax_loss` function in `cs231n/layers.py`. These should be similar to what you implemented in `cs231n/classifiers/softmax.py`. Other loss functions (e.g. `svm_loss`) can also be implemented in a modular way, however, it is not required for this assignment.
#
# You can make sure that the implementations are correct by running the following:

# %%
from cs231n.layers import softmax_loss

# %%
from cs231n.layers import softmax_loss
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)


dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3025458445007376
# dx error:  8.234144091578429e-09

# %% [markdown]
# # Two-layer network
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. Read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %% [markdown]
# # Solver
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves about `36%` accuracy on the validation set.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.20e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 9.09e-10

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
model = TwoLayerNet(input_size, hidden_size, num_classes)
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves about 36% #
# accuracy on the validation set.                                            #
##############################################################################

# data = {
#   'X_train': # training data
#   'y_train': # training labels
#   'X_val': # validation data
#   'y_val': # validation labels
# }
# model = MyAwesomeModel(hidden_size=100, reg=10)
solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 1e-4,
                },
                lr_decay=0.95,
                num_epochs=5, batch_size=200,
                print_every=100)
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.303922
# (Epoch 0 / 5) train acc: 0.069000; val_acc: 0.063000
# (Iteration 101 / 1225) loss: 2.280164
# (Iteration 201 / 1225) loss: 2.176490
# (Epoch 1 / 5) train acc: 0.211000; val_acc: 0.257000
# (Iteration 301 / 1225) loss: 2.104870
# (Iteration 401 / 1225) loss: 1.997602
# (Epoch 2 / 5) train acc: 0.294000; val_acc: 0.293000
# (Iteration 501 / 1225) loss: 1.929971
# (Iteration 601 / 1225) loss: 2.006990
# (Iteration 701 / 1225) loss: 1.811825
# (Epoch 3 / 5) train acc: 0.345000; val_acc: 0.332000
# (Iteration 801 / 1225) loss: 1.792892
# (Iteration 901 / 1225) loss: 1.808718
# (Epoch 4 / 5) train acc: 0.370000; val_acc: 0.363000
# (Iteration 1001 / 1225) loss: 1.892665
# (Iteration 1101 / 1225) loss: 1.767647
# (Iteration 1201 / 1225) loss: 1.700919
# (Epoch 5 / 5) train acc: 0.376000; val_acc: 0.372000

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.36 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(model)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (52% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_model = None



#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_model.                                                          #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on thexs previous exercises.                          #
#################################################################################
# hidden layer size, learning rate, numer of training epochs, and regularization
# strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.

# previous parameter package:
# input_size = 32 * 32 * 3
# hidden_size = 50
# num_classes = 10
# model = TwoLayerNet(input_size, hidden_size, num_classes)
# model = MyAwesomeModel(hidden_size=50, reg=0)
# solver = Solver(model, data,
#                 update_rule='sgd',
#                 optim_config={
#                   'learning_rate': 1e-4,
#                 },
#                 lr_decay=0.95,
#                 num_epochs=5, batch_size=200,
#                 print_every=100)

results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
# best_softmax = None # The Softmax object that achieved the highest validation rate.


# Provided as a reference. You may or may not want to change these hyperparameters
best_hidden_layer_size = None
best_learning_rate = None
best_training_epochs = None
best_regularization_strength = None

# learning_rates = range([1e-9, 1e-2])
# regularization_strengths = range([1e-6, 1e6])
# Generate hyperparameter values on logarithmic scale
learning_rates = np.logspace(-4, -2, num=4)  # [1e-9, 1e-8, ..., 1e-2]
regularization_strengths = np.logspace(-6, 6, num=4)  # [1e-6, 1e-4, ..., 1e6]

for learning_rate in learning_rates:
  for regularization_strength in regularization_strengths:
    model = TwoLayerNet(input_size, hidden_size, num_classes, reg=regularization_strength)

    tic = time.time()
    solver = Solver(model, data,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    lr_decay=0.95,
                    num_epochs=5, batch_size=200,
                    print_every=100)
    solver.train()


    # plt.plot(solver.loss_history, 'o')
    # plt.xlabel('Iteration')

    # plt.subplot(2, 1, 2)
    # plt.title('Accuracy')
    # plt.plot(solver.train_acc_history, '-o', label='train')
    # plt.plot(solver.val_acc_history, '-o', label='val')

    # y_train_pred = solver.predict(data['X_train'])
    # y_val_pred = solver.predict(data['X_val'])



    # training_accuracy = np.mean(data['y_train'] == y_train_pred)
    # validation_accuracy = np.mean(data['y_val'] == y_val_pred)
    training_accuracy = solver.check_accuracy(data['X_train'], data['y_train'], num_samples=None, batch_size=200)
    validation_accuracy = solver.check_accuracy(data['X_val'], data['y_val'], num_samples=None, batch_size=200)
    # results[(learning_rate,regularization_strength)] = [training_accuracy, validation_accuracy]
    results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)


    if validation_accuracy > best_val:
      best_val = validation_accuracy
      best_model = model
      best_learning_rate = learning_rate
      best_regularization_strength = regularization_strength



# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' % best_val)
print('best learning rate: %e' % best_learning_rate)
print('best regularization strength: %e' % best_regularization_strength)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.303084
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.098000
# (Iteration 101 / 1225) loss: 2.256580
# (Iteration 201 / 1225) loss: 2.179606
# (Epoch 1 / 5) train acc: 0.266000; val_acc: 0.250000
# (Iteration 301 / 1225) loss: 2.085785
# (Iteration 401 / 1225) loss: 2.030266
# (Epoch 2 / 5) train acc: 0.279000; val_acc: 0.298000
# (Iteration 501 / 1225) loss: 2.023153
# (Iteration 601 / 1225) loss: 1.802952
# (Iteration 701 / 1225) loss: 1.830258
# (Epoch 3 / 5) train acc: 0.328000; val_acc: 0.330000
# (Iteration 801 / 1225) loss: 1.854079
# (Iteration 901 / 1225) loss: 1.756000
# (Epoch 4 / 5) train acc: 0.361000; val_acc: 0.357000
# (Iteration 1001 / 1225) loss: 1.778241
# (Iteration 1101 / 1225) loss: 1.833988
# (Iteration 1201 / 1225) loss: 1.774829
# (Epoch 5 / 5) train acc: 0.383000; val_acc: 0.375000
# (Iteration 1 / 1225) loss: 77124.125478
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.122000
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/layers.py:804: RuntimeWarning: divide by zero encountered in log
#   log_probs = np.log(probs)  # (N, C)
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/classifiers/fc_net.py:167: RuntimeWarning: overflow encountered in scalar multiply
#   reg_loss = 0.5 * self.reg * (np.sum(W1**2) + np.sum(W2**2))
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/layers.py:38: RuntimeWarning: overflow encountered in matmul
#   out = x_reshaped @ w + b
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/layers.py:782: RuntimeWarning: invalid value encountered in subtract
#   scores = scores - np.max(scores, axis=1, keepdims=True) # missed this line, lead to results dx error 0.3333
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.084000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.114000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.101000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.106000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.092000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 2.304861
# (Epoch 0 / 5) train acc: 0.157000; val_acc: 0.159000
# (Iteration 101 / 1225) loss: inf
# (Iteration 201 / 1225) loss: inf
# (Epoch 1 / 5) train acc: 0.060000; val_acc: 0.058000
# (Iteration 301 / 1225) loss: inf
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/layers.py:782: RuntimeWarning: overflow encountered in subtract
#   scores = scores - np.max(scores, axis=1, keepdims=True) # missed this line, lead to results dx error 0.3333
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.098000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.103000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.088000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.101000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 77169.210973
# (Epoch 0 / 5) train acc: 0.074000; val_acc: 0.098000
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.112000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.109000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.107000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.113000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.093000; val_acc: 0.087000
# lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.369490 val accuracy: 0.375000
# lr 1.000000e-04 reg 1.000000e+06 train accuracy: 0.112939 val accuracy: 0.122000
# lr 1.000000e-02 reg 1.000000e-06 train accuracy: 0.172735 val accuracy: 0.159000
# lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.090041 val accuracy: 0.098000
# best validation accuracy achieved during cross-validation: 0.375000
# best learning rate: 1.000000e-04
# best regularization strength: 1.000000e-06

# %%
best_model = None



#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_model.                                                          #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on thexs previous exercises.                          #
#################################################################################
# hidden layer size, learning rate, numer of training epochs, and regularization
# strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.

# previous parameter package:
# input_size = 32 * 32 * 3
# hidden_size = 50
# num_classes = 10
# model = TwoLayerNet(input_size, hidden_size, num_classes)
# model = MyAwesomeModel(hidden_size=50, reg=0)
# solver = Solver(model, data,
#                 update_rule='sgd',
#                 optim_config={
#                   'learning_rate': 1e-4,
#                 },
#                 lr_decay=0.95,
#                 num_epochs=5, batch_size=200,
#                 print_every=100)

results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
# best_softmax = None # The Softmax object that achieved the highest validation rate.


# Provided as a reference. You may or may not want to change these hyperparameters
best_hidden_layer_size = None
best_learning_rate = None
best_training_epochs = None
best_regularization_strength = None

# learning_rates = range([1e-9, 1e-2])
# regularization_strengths = range([1e-6, 1e6])
# Generate hyperparameter values on logarithmic scale
learning_rates = np.logspace(-4, -2, num=4)  # [1e-9, 1e-8, ..., 1e-2]
regularization_strengths = np.logspace(-6, 6, num=4)  # [1e-6, 1e-4, ..., 1e6]

for learning_rate in learning_rates:
  for regularization_strength in regularization_strengths:
    model = TwoLayerNet(input_size, hidden_size, num_classes, reg=regularization_strength)

    tic = time.time()
    solver = Solver(model, data,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    lr_decay=0.95,
                    num_epochs=5, batch_size=200,
                    print_every=100)
    solver.train()


    # plt.plot(solver.loss_history, 'o')
    # plt.xlabel('Iteration')

    # plt.subplot(2, 1, 2)
    # plt.title('Accuracy')
    # plt.plot(solver.train_acc_history, '-o', label='train')
    # plt.plot(solver.val_acc_history, '-o', label='val')

    # y_train_pred = solver.predict(data['X_train'])
    # y_val_pred = solver.predict(data['X_val'])



    # training_accuracy = np.mean(data['y_train'] == y_train_pred)
    # validation_accuracy = np.mean(data['y_val'] == y_val_pred)
    training_accuracy = solver.check_accuracy(data['X_train'], data['y_train'], num_samples=None, batch_size=200)
    validation_accuracy = solver.check_accuracy(data['X_val'], data['y_val'], num_samples=None, batch_size=200)
    # results[(learning_rate,regularization_strength)] = [training_accuracy, validation_accuracy]
    results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)


    if validation_accuracy > best_val:
      best_val = validation_accuracy
      best_model = model
      best_learning_rate = learning_rate
      best_regularization_strength = regularization_strength



# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' % best_val)
print('best learning rate: %e' % best_learning_rate)
print('best regularization strength: %e' % best_regularization_strength)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.303058
# (Epoch 0 / 5) train acc: 0.079000; val_acc: 0.086000
# (Iteration 101 / 1225) loss: 2.255360
# (Iteration 201 / 1225) loss: 2.161289
# (Epoch 1 / 5) train acc: 0.242000; val_acc: 0.261000
# (Iteration 301 / 1225) loss: 2.064304
# (Iteration 401 / 1225) loss: 1.949885
# (Epoch 2 / 5) train acc: 0.271000; val_acc: 0.293000
# (Iteration 501 / 1225) loss: 1.949128
# (Iteration 601 / 1225) loss: 1.910448
# (Iteration 701 / 1225) loss: 1.833241
# (Epoch 3 / 5) train acc: 0.331000; val_acc: 0.322000
# (Iteration 801 / 1225) loss: 1.882677
# (Iteration 901 / 1225) loss: 1.823974
# (Epoch 4 / 5) train acc: 0.357000; val_acc: 0.356000
# (Iteration 1001 / 1225) loss: 1.918917
# (Iteration 1101 / 1225) loss: 1.823267
# (Iteration 1201 / 1225) loss: 1.753598
# (Epoch 5 / 5) train acc: 0.381000; val_acc: 0.377000
# (Iteration 1 / 1225) loss: 2.301922
# (Epoch 0 / 5) train acc: 0.106000; val_acc: 0.110000
# (Iteration 101 / 1225) loss: 2.273706
# (Iteration 201 / 1225) loss: 2.124229
# (Epoch 1 / 5) train acc: 0.242000; val_acc: 0.259000
# (Iteration 301 / 1225) loss: 2.068853
# (Iteration 401 / 1225) loss: 1.963966
# (Epoch 2 / 5) train acc: 0.304000; val_acc: 0.294000
# (Iteration 501 / 1225) loss: 1.946238
# (Iteration 601 / 1225) loss: 1.893584
# (Iteration 701 / 1225) loss: 1.887297
# (Epoch 3 / 5) train acc: 0.335000; val_acc: 0.324000
# (Iteration 801 / 1225) loss: 1.797901
# (Iteration 901 / 1225) loss: 1.841412
# (Epoch 4 / 5) train acc: 0.368000; val_acc: 0.354000
# (Iteration 1001 / 1225) loss: 1.732624
# (Iteration 1101 / 1225) loss: 1.858901
# (Iteration 1201 / 1225) loss: 1.826398
# (Epoch 5 / 5) train acc: 0.389000; val_acc: 0.359000
# (Iteration 1 / 1225) loss: 10.006253
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.112000
# (Iteration 101 / 1225) loss: 3.331695
# (Iteration 201 / 1225) loss: 2.437584
# (Epoch 1 / 5) train acc: 0.153000; val_acc: 0.160000
# (Iteration 301 / 1225) loss: 2.319646
# (Iteration 401 / 1225) loss: 2.295460
# (Epoch 2 / 5) train acc: 0.207000; val_acc: 0.193000
# (Iteration 501 / 1225) loss: 2.298705
# (Iteration 601 / 1225) loss: 2.298812
# (Iteration 701 / 1225) loss: 2.293219
# (Epoch 3 / 5) train acc: 0.138000; val_acc: 0.155000
# (Iteration 801 / 1225) loss: 2.298444
# (Iteration 901 / 1225) loss: 2.292849
# (Epoch 4 / 5) train acc: 0.149000; val_acc: 0.183000
# (Iteration 1001 / 1225) loss: 2.304597
# (Iteration 1101 / 1225) loss: 2.301522
# (Iteration 1201 / 1225) loss: 2.302529
# (Epoch 5 / 5) train acc: 0.162000; val_acc: 0.180000
# (Iteration 1 / 1225) loss: 77031.747222
# (Epoch 0 / 5) train acc: 0.142000; val_acc: 0.106000
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.107000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.101000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.100000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.106000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.095000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 2.302482
# (Epoch 0 / 5) train acc: 0.104000; val_acc: 0.102000
# (Iteration 101 / 1225) loss: 1.966112
# (Iteration 201 / 1225) loss: 1.736367
# (Epoch 1 / 5) train acc: 0.362000; val_acc: 0.374000
# (Iteration 301 / 1225) loss: 1.694239
# (Iteration 401 / 1225) loss: 1.741154
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.431000
# (Iteration 501 / 1225) loss: 1.608100
# (Iteration 601 / 1225) loss: 1.710124
# (Iteration 701 / 1225) loss: 1.527355
# (Epoch 3 / 5) train acc: 0.442000; val_acc: 0.447000
# (Iteration 801 / 1225) loss: 1.498425
# (Iteration 901 / 1225) loss: 1.412829
# (Epoch 4 / 5) train acc: 0.465000; val_acc: 0.462000
# (Iteration 1001 / 1225) loss: 1.512270
# (Iteration 1101 / 1225) loss: 1.372377
# (Iteration 1201 / 1225) loss: 1.489959
# (Epoch 5 / 5) train acc: 0.489000; val_acc: 0.478000
# (Iteration 1 / 1225) loss: 2.304804
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.108000
# (Iteration 101 / 1225) loss: 2.023971
# (Iteration 201 / 1225) loss: 1.802194
# (Epoch 1 / 5) train acc: 0.389000; val_acc: 0.373000
# (Iteration 301 / 1225) loss: 1.719395
# (Iteration 401 / 1225) loss: 1.694630
# (Epoch 2 / 5) train acc: 0.413000; val_acc: 0.420000
# (Iteration 501 / 1225) loss: 1.557323
# (Iteration 601 / 1225) loss: 1.580204
# (Iteration 701 / 1225) loss: 1.470719
# (Epoch 3 / 5) train acc: 0.459000; val_acc: 0.456000
# (Iteration 801 / 1225) loss: 1.534636
# (Iteration 901 / 1225) loss: 1.555786
# (Epoch 4 / 5) train acc: 0.477000; val_acc: 0.469000
# (Iteration 1001 / 1225) loss: 1.493971
# (Iteration 1101 / 1225) loss: 1.560468
# (Iteration 1201 / 1225) loss: 1.418655
# (Epoch 5 / 5) train acc: 0.481000; val_acc: 0.473000
# (Iteration 1 / 1225) loss: 10.001971
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.112000
# (Iteration 101 / 1225) loss: 2.296153
# (Iteration 201 / 1225) loss: 2.301406
# (Epoch 1 / 5) train acc: 0.170000; val_acc: 0.181000
# (Iteration 301 / 1225) loss: 2.306504
# (Iteration 401 / 1225) loss: 2.294819
# (Epoch 2 / 5) train acc: 0.147000; val_acc: 0.177000
# (Iteration 501 / 1225) loss: 2.292859
# (Iteration 601 / 1225) loss: 2.297762
# (Iteration 701 / 1225) loss: 2.313069
# (Epoch 3 / 5) train acc: 0.166000; val_acc: 0.157000
# (Iteration 801 / 1225) loss: 2.288411
# (Iteration 901 / 1225) loss: 2.301939
# (Epoch 4 / 5) train acc: 0.155000; val_acc: 0.181000
# (Iteration 1001 / 1225) loss: 2.305839
# (Iteration 1101 / 1225) loss: 2.286527
# (Iteration 1201 / 1225) loss: 2.290713
# (Epoch 5 / 5) train acc: 0.172000; val_acc: 0.179000
# (Iteration 1 / 1225) loss: 76747.287025
# (Epoch 0 / 5) train acc: 0.125000; val_acc: 0.110000
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/classifiers/fc_net.py:167: RuntimeWarning: overflow encountered in square
#   reg_loss = 0.5 * self.reg * (np.sum(W1**2) + np.sum(W2**2))
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.107000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.107000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.102000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.099000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.096000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 2.302307
# (Epoch 0 / 5) train acc: 0.140000; val_acc: 0.135000
# (Iteration 101 / 1225) loss: 1.769117
# (Iteration 201 / 1225) loss: 1.825756
# (Epoch 1 / 5) train acc: 0.448000; val_acc: 0.426000
# (Iteration 301 / 1225) loss: 1.660058
# (Iteration 401 / 1225) loss: 1.593475
# (Epoch 2 / 5) train acc: 0.416000; val_acc: 0.407000
# (Iteration 501 / 1225) loss: 1.481557
# (Iteration 601 / 1225) loss: 1.518718
# (Iteration 701 / 1225) loss: 1.568444
# (Epoch 3 / 5) train acc: 0.501000; val_acc: 0.472000
# (Iteration 801 / 1225) loss: 1.523353
# (Iteration 901 / 1225) loss: 1.586578
# (Epoch 4 / 5) train acc: 0.486000; val_acc: 0.454000
# (Iteration 1001 / 1225) loss: 1.255500
# (Iteration 1101 / 1225) loss: 1.324170
# (Iteration 1201 / 1225) loss: 1.402946
# (Epoch 5 / 5) train acc: 0.528000; val_acc: 0.473000
# (Iteration 1 / 1225) loss: 2.304790
# (Epoch 0 / 5) train acc: 0.124000; val_acc: 0.155000
# (Iteration 101 / 1225) loss: 1.752970
# (Iteration 201 / 1225) loss: 1.582213
# (Epoch 1 / 5) train acc: 0.398000; val_acc: 0.394000
# (Iteration 301 / 1225) loss: 1.380282
# (Iteration 401 / 1225) loss: 1.559657
# (Epoch 2 / 5) train acc: 0.480000; val_acc: 0.446000
# (Iteration 501 / 1225) loss: 1.442235
# (Iteration 601 / 1225) loss: 1.604586
# (Iteration 701 / 1225) loss: 1.668101
# (Epoch 3 / 5) train acc: 0.466000; val_acc: 0.433000
# (Iteration 801 / 1225) loss: 1.528193
# (Iteration 901 / 1225) loss: 1.414743
# (Epoch 4 / 5) train acc: 0.458000; val_acc: 0.456000
# (Iteration 1001 / 1225) loss: 1.464828
# (Iteration 1101 / 1225) loss: 1.590311
# (Iteration 1201 / 1225) loss: 1.463902
# (Epoch 5 / 5) train acc: 0.483000; val_acc: 0.457000
# (Iteration 1 / 1225) loss: 10.002496
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.122000
# (Iteration 101 / 1225) loss: 2.302604
# (Iteration 201 / 1225) loss: 2.287568
# (Epoch 1 / 5) train acc: 0.148000; val_acc: 0.154000
# (Iteration 301 / 1225) loss: 2.326240
# (Iteration 401 / 1225) loss: 2.291539
# (Epoch 2 / 5) train acc: 0.165000; val_acc: 0.180000
# (Iteration 501 / 1225) loss: 2.292039
# (Iteration 601 / 1225) loss: 2.314025
# (Iteration 701 / 1225) loss: 2.295586
# (Epoch 3 / 5) train acc: 0.158000; val_acc: 0.178000
# (Iteration 801 / 1225) loss: 2.286374
# (Iteration 901 / 1225) loss: 2.298157
# (Epoch 4 / 5) train acc: 0.148000; val_acc: 0.180000
# (Iteration 1001 / 1225) loss: 2.297868
# (Iteration 1101 / 1225) loss: 2.292399
# (Iteration 1201 / 1225) loss: 2.287936
# (Epoch 5 / 5) train acc: 0.162000; val_acc: 0.182000
# (Iteration 1 / 1225) loss: 77493.244515
# (Epoch 0 / 5) train acc: 0.112000; val_acc: 0.120000
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.096000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.096000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.082000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.095000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.094000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 2.304373
# (Epoch 0 / 5) train acc: 0.185000; val_acc: 0.174000
# (Iteration 101 / 1225) loss: inf
# (Iteration 201 / 1225) loss: inf
# (Epoch 1 / 5) train acc: 0.167000; val_acc: 0.150000
# (Iteration 301 / 1225) loss: inf
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.086000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.126000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.096000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.099000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 2.303905
# (Epoch 0 / 5) train acc: 0.163000; val_acc: 0.177000
# (Iteration 101 / 1225) loss: inf
# (Iteration 201 / 1225) loss: inf
# (Epoch 1 / 5) train acc: 0.076000; val_acc: 0.057000
# (Iteration 301 / 1225) loss: inf
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.097000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.113000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.102000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.111000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 9.934769
# (Epoch 0 / 5) train acc: 0.086000; val_acc: 0.119000
# (Iteration 101 / 1225) loss: inf
# (Iteration 201 / 1225) loss: inf
# (Epoch 1 / 5) train acc: 0.042000; val_acc: 0.044000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.128000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.096000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.104000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.092000; val_acc: 0.087000
# (Iteration 1 / 1225) loss: 77037.674367
# (Epoch 0 / 5) train acc: 0.142000; val_acc: 0.142000
# (Iteration 101 / 1225) loss: nan
# (Iteration 201 / 1225) loss: nan
# (Epoch 1 / 5) train acc: 0.091000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: nan
# (Iteration 401 / 1225) loss: nan
# (Epoch 2 / 5) train acc: 0.105000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: nan
# (Iteration 601 / 1225) loss: nan
# (Iteration 701 / 1225) loss: nan
# (Epoch 3 / 5) train acc: 0.105000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: nan
# (Iteration 901 / 1225) loss: nan
# (Epoch 4 / 5) train acc: 0.090000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: nan
# (Iteration 1101 / 1225) loss: nan
# (Iteration 1201 / 1225) loss: nan
# (Epoch 5 / 5) train acc: 0.094000; val_acc: 0.087000
# lr 1.000000e-04 reg 1.000000e-06 train accuracy: 0.369837 val accuracy: 0.377000
# lr 1.000000e-04 reg 1.000000e-02 train accuracy: 0.366735 val accuracy: 0.359000
# lr 1.000000e-04 reg 1.000000e+02 train accuracy: 0.181265 val accuracy: 0.193000
# lr 1.000000e-04 reg 1.000000e+06 train accuracy: 0.112408 val accuracy: 0.106000
# lr 4.641589e-04 reg 1.000000e-06 train accuracy: 0.481857 val accuracy: 0.478000
# lr 4.641589e-04 reg 1.000000e-02 train accuracy: 0.484122 val accuracy: 0.473000
# lr 4.641589e-04 reg 1.000000e+02 train accuracy: 0.160327 val accuracy: 0.181000
# lr 4.641589e-04 reg 1.000000e+06 train accuracy: 0.125776 val accuracy: 0.110000
# lr 2.154435e-03 reg 1.000000e-06 train accuracy: 0.515490 val accuracy: 0.473000
# lr 2.154435e-03 reg 1.000000e-02 train accuracy: 0.488102 val accuracy: 0.457000
# lr 2.154435e-03 reg 1.000000e+02 train accuracy: 0.162980 val accuracy: 0.182000
# lr 2.154435e-03 reg 1.000000e+06 train accuracy: 0.110388 val accuracy: 0.120000
# lr 1.000000e-02 reg 1.000000e-06 train accuracy: 0.191204 val accuracy: 0.174000
# lr 1.000000e-02 reg 1.000000e-02 train accuracy: 0.166102 val accuracy: 0.177000
# lr 1.000000e-02 reg 1.000000e+02 train accuracy: 0.099612 val accuracy: 0.119000
# lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.135959 val accuracy: 0.142000
# best validation accuracy achieved during cross-validation: 0.478000
# best learning rate: 4.641589e-04
# best regularization strength: 1.000000e-06

# %%
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %% [markdown]
# best validation accuracy achieved during cross-validation: 0.478000
# best learning rate: 4.641589e-04
# best regularization strength: 1.000000e-06

# %%
best_learning_rate = 4.641589e-04
best_regularization_strength = 1.000000e-06
best_model = None


results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
# best_softmax = None # The Softmax object that achieved the highest validation rate.

# Provided as a reference. You may or may not want to change these hyperparameters
best_hidden_layer_size = None
# best_learning_rate = None
best_training_epochs = None
# best_regularization_strength = None


# input_size = 32 * 32 * 3
# hidden_size = 50
# num_classes = 10
# Generate hyperparameter values on logarithmic scale

# best_hidden_layer_size = np.logspace(-4, -2, num=4)  # [1e-9, 1e-8, ..., 1e-2]
hidden_sizes = [50, 100, 150]
training_epochs = [5, 10, 20]


for hidden_size in hidden_sizes:
  for training_epoch in training_epochs:
    model = TwoLayerNet(input_size, hidden_size, num_classes, reg=best_regularization_strength)

    tic = time.time()
    solver = Solver(model, data,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': best_learning_rate,
                    },
                    lr_decay=0.95,
                    num_epochs=training_epoch, batch_size=200,
                    print_every=100)
    solver.train()


    # plt.plot(solver.loss_history, 'o')
    # plt.xlabel('Iteration')

    # plt.subplot(2, 1, 2)
    # plt.title('Accuracy')
    # plt.plot(solver.train_acc_history, '-o', label='train')
    # plt.plot(solver.val_acc_history, '-o', label='val')

    # y_train_pred = solver.predict(data['X_train'])
    # y_val_pred = solver.predict(data['X_val'])



    # training_accuracy = np.mean(data['y_train'] == y_train_pred)
    # validation_accuracy = np.mean(data['y_val'] == y_val_pred)
    training_accuracy = solver.check_accuracy(data['X_train'], data['y_train'], num_samples=None, batch_size=200)
    validation_accuracy = solver.check_accuracy(data['X_val'], data['y_val'], num_samples=None, batch_size=200)
    # results[(learning_rate,regularization_strength)] = [training_accuracy, validation_accuracy]
    results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)


    if validation_accuracy > best_val:
      best_val = validation_accuracy
      best_model = model
      best_hidden_size = hidden_size
      best_training_epoch = training_epoch



# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' % best_val)
print('best_hidden_size: %e' % best_hidden_size)
print('best_training_epoch: %e' % best_training_epoch)

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 1225) loss: 2.301789
# (Epoch 0 / 5) train acc: 0.122000; val_acc: 0.133000
# (Iteration 101 / 1225) loss: 2.032101
# (Iteration 201 / 1225) loss: 1.692969
# (Epoch 1 / 5) train acc: 0.374000; val_acc: 0.375000
# (Iteration 301 / 1225) loss: 1.629346
# (Iteration 401 / 1225) loss: 1.730070
# (Epoch 2 / 5) train acc: 0.422000; val_acc: 0.425000
# (Iteration 501 / 1225) loss: 1.679103
# (Iteration 601 / 1225) loss: 1.571954
# (Iteration 701 / 1225) loss: 1.666872
# (Epoch 3 / 5) train acc: 0.453000; val_acc: 0.446000
# (Iteration 801 / 1225) loss: 1.690276
# (Iteration 901 / 1225) loss: 1.490221
# (Epoch 4 / 5) train acc: 0.455000; val_acc: 0.448000
# (Iteration 1001 / 1225) loss: 1.467280
# (Iteration 1101 / 1225) loss: 1.416421
# (Iteration 1201 / 1225) loss: 1.416052
# (Epoch 5 / 5) train acc: 0.469000; val_acc: 0.460000
# (Iteration 1 / 2450) loss: 2.302950
# (Epoch 0 / 10) train acc: 0.096000; val_acc: 0.092000
# (Iteration 101 / 2450) loss: 2.021467
# (Iteration 201 / 2450) loss: 1.791328
# (Epoch 1 / 10) train acc: 0.377000; val_acc: 0.386000
# (Iteration 301 / 2450) loss: 1.667221
# (Iteration 401 / 2450) loss: 1.754050
# (Epoch 2 / 10) train acc: 0.427000; val_acc: 0.413000
# (Iteration 501 / 2450) loss: 1.613033
# (Iteration 601 / 2450) loss: 1.698347
# (Iteration 701 / 2450) loss: 1.526904
# (Epoch 3 / 10) train acc: 0.465000; val_acc: 0.456000
# (Iteration 801 / 2450) loss: 1.497641
# (Iteration 901 / 2450) loss: 1.612827
# (Epoch 4 / 10) train acc: 0.458000; val_acc: 0.460000
# (Iteration 1001 / 2450) loss: 1.515377
# (Iteration 1101 / 2450) loss: 1.425746
# (Iteration 1201 / 2450) loss: 1.553144
# (Epoch 5 / 10) train acc: 0.466000; val_acc: 0.464000
# (Iteration 1301 / 2450) loss: 1.423726
# (Iteration 1401 / 2450) loss: 1.552929
# (Epoch 6 / 10) train acc: 0.499000; val_acc: 0.469000
# (Iteration 1501 / 2450) loss: 1.394253
# (Iteration 1601 / 2450) loss: 1.428813
# (Iteration 1701 / 2450) loss: 1.370074
# (Epoch 7 / 10) train acc: 0.525000; val_acc: 0.482000
# (Iteration 1801 / 2450) loss: 1.411563
# (Iteration 1901 / 2450) loss: 1.315194
# (Epoch 8 / 10) train acc: 0.486000; val_acc: 0.484000
# (Iteration 2001 / 2450) loss: 1.298796
# (Iteration 2101 / 2450) loss: 1.399002
# (Iteration 2201 / 2450) loss: 1.279509
# (Epoch 9 / 10) train acc: 0.530000; val_acc: 0.497000
# (Iteration 2301 / 2450) loss: 1.323893
# (Iteration 2401 / 2450) loss: 1.507946
# (Epoch 10 / 10) train acc: 0.512000; val_acc: 0.496000
# (Iteration 1 / 4900) loss: 2.301398
# (Epoch 0 / 20) train acc: 0.119000; val_acc: 0.106000
# (Iteration 101 / 4900) loss: 1.952643
# (Iteration 201 / 4900) loss: 1.823542
# (Epoch 1 / 20) train acc: 0.361000; val_acc: 0.375000
# (Iteration 301 / 4900) loss: 1.713387
# (Iteration 401 / 4900) loss: 1.677526
# (Epoch 2 / 20) train acc: 0.415000; val_acc: 0.428000
# (Iteration 501 / 4900) loss: 1.611454
# (Iteration 601 / 4900) loss: 1.674791
# (Iteration 701 / 4900) loss: 1.701761
# (Epoch 3 / 20) train acc: 0.460000; val_acc: 0.454000
# (Iteration 801 / 4900) loss: 1.577484
# (Iteration 901 / 4900) loss: 1.664482
# (Epoch 4 / 20) train acc: 0.473000; val_acc: 0.452000
# (Iteration 1001 / 4900) loss: 1.579914
# (Iteration 1101 / 4900) loss: 1.424511
# (Iteration 1201 / 4900) loss: 1.613658
# (Epoch 5 / 20) train acc: 0.460000; val_acc: 0.458000
# (Iteration 1301 / 4900) loss: 1.373834
# (Iteration 1401 / 4900) loss: 1.586893
# (Epoch 6 / 20) train acc: 0.495000; val_acc: 0.481000
# (Iteration 1501 / 4900) loss: 1.373057
# (Iteration 1601 / 4900) loss: 1.322917
# (Iteration 1701 / 4900) loss: 1.426311
# (Epoch 7 / 20) train acc: 0.504000; val_acc: 0.476000
# (Iteration 1801 / 4900) loss: 1.354095
# (Iteration 1901 / 4900) loss: 1.530341
# (Epoch 8 / 20) train acc: 0.518000; val_acc: 0.490000
# (Iteration 2001 / 4900) loss: 1.507945
# (Iteration 2101 / 4900) loss: 1.376239
# (Iteration 2201 / 4900) loss: 1.277207
# (Epoch 9 / 20) train acc: 0.522000; val_acc: 0.501000
# (Iteration 2301 / 4900) loss: 1.305038
# (Iteration 2401 / 4900) loss: 1.308485
# (Epoch 10 / 20) train acc: 0.505000; val_acc: 0.506000
# (Iteration 2501 / 4900) loss: 1.349863
# (Iteration 2601 / 4900) loss: 1.303588
# (Epoch 11 / 20) train acc: 0.549000; val_acc: 0.509000
# (Iteration 2701 / 4900) loss: 1.386501
# (Iteration 2801 / 4900) loss: 1.413077
# (Iteration 2901 / 4900) loss: 1.312296
# (Epoch 12 / 20) train acc: 0.528000; val_acc: 0.505000
# (Iteration 3001 / 4900) loss: 1.273435
# (Iteration 3101 / 4900) loss: 1.357744
# (Epoch 13 / 20) train acc: 0.558000; val_acc: 0.514000
# (Iteration 3201 / 4900) loss: 1.402101
# (Iteration 3301 / 4900) loss: 1.290842
# (Iteration 3401 / 4900) loss: 1.384250
# (Epoch 14 / 20) train acc: 0.526000; val_acc: 0.503000
# (Iteration 3501 / 4900) loss: 1.425261
# (Iteration 3601 / 4900) loss: 1.237749
# (Epoch 15 / 20) train acc: 0.535000; val_acc: 0.517000
# (Iteration 3701 / 4900) loss: 1.371681
# (Iteration 3801 / 4900) loss: 1.473656
# (Iteration 3901 / 4900) loss: 1.284281
# (Epoch 16 / 20) train acc: 0.537000; val_acc: 0.508000
# (Iteration 4001 / 4900) loss: 1.360837
# (Iteration 4101 / 4900) loss: 1.278472
# (Epoch 17 / 20) train acc: 0.532000; val_acc: 0.525000
# (Iteration 4201 / 4900) loss: 1.147574
# (Iteration 4301 / 4900) loss: 1.275451
# (Iteration 4401 / 4900) loss: 1.260315
# (Epoch 18 / 20) train acc: 0.584000; val_acc: 0.513000
# (Iteration 4501 / 4900) loss: 1.194107
# (Iteration 4601 / 4900) loss: 1.452718
# (Epoch 19 / 20) train acc: 0.563000; val_acc: 0.526000
# (Iteration 4701 / 4900) loss: 1.286080
# (Iteration 4801 / 4900) loss: 1.334083
# (Epoch 20 / 20) train acc: 0.578000; val_acc: 0.510000
# (Iteration 1 / 1225) loss: 2.302744
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.141000
# (Iteration 101 / 1225) loss: 1.870740
# (Iteration 201 / 1225) loss: 1.712508
# (Epoch 1 / 5) train acc: 0.390000; val_acc: 0.384000
# (Iteration 301 / 1225) loss: 1.679707
# (Iteration 401 / 1225) loss: 1.709159
# (Epoch 2 / 5) train acc: 0.421000; val_acc: 0.446000
# (Iteration 501 / 1225) loss: 1.595769
# (Iteration 601 / 1225) loss: 1.476701
# (Iteration 701 / 1225) loss: 1.491562
# (Epoch 3 / 5) train acc: 0.456000; val_acc: 0.464000
# (Iteration 801 / 1225) loss: 1.549460
# (Iteration 901 / 1225) loss: 1.541724
# (Epoch 4 / 5) train acc: 0.500000; val_acc: 0.475000
# (Iteration 1001 / 1225) loss: 1.427382
# (Iteration 1101 / 1225) loss: 1.543133
# (Iteration 1201 / 1225) loss: 1.404841
# (Epoch 5 / 5) train acc: 0.495000; val_acc: 0.478000
# (Iteration 1 / 2450) loss: 2.300651
# (Epoch 0 / 10) train acc: 0.121000; val_acc: 0.124000
# (Iteration 101 / 2450) loss: 1.883226
# (Iteration 201 / 2450) loss: 1.761113
# (Epoch 1 / 10) train acc: 0.366000; val_acc: 0.383000
# (Iteration 301 / 2450) loss: 1.715829
# (Iteration 401 / 2450) loss: 1.600545
# (Epoch 2 / 10) train acc: 0.432000; val_acc: 0.440000
# (Iteration 501 / 2450) loss: 1.692634
# (Iteration 601 / 2450) loss: 1.585070
# (Iteration 701 / 2450) loss: 1.627031
# (Epoch 3 / 10) train acc: 0.466000; val_acc: 0.473000
# (Iteration 801 / 2450) loss: 1.612788
# (Iteration 901 / 2450) loss: 1.549827
# (Epoch 4 / 10) train acc: 0.471000; val_acc: 0.476000
# (Iteration 1001 / 2450) loss: 1.434456
# (Iteration 1101 / 2450) loss: 1.586317
# (Iteration 1201 / 2450) loss: 1.404299
# (Epoch 5 / 10) train acc: 0.474000; val_acc: 0.488000
# (Iteration 1301 / 2450) loss: 1.532867
# (Iteration 1401 / 2450) loss: 1.342269
# (Epoch 6 / 10) train acc: 0.513000; val_acc: 0.491000
# (Iteration 1501 / 2450) loss: 1.407216
# (Iteration 1601 / 2450) loss: 1.379252
# (Iteration 1701 / 2450) loss: 1.364460
# (Epoch 7 / 10) train acc: 0.559000; val_acc: 0.496000
# (Iteration 1801 / 2450) loss: 1.239358
# (Iteration 1901 / 2450) loss: 1.268326
# (Epoch 8 / 10) train acc: 0.546000; val_acc: 0.503000
# (Iteration 2001 / 2450) loss: 1.436817
# (Iteration 2101 / 2450) loss: 1.398705
# (Iteration 2201 / 2450) loss: 1.143264
# (Epoch 9 / 10) train acc: 0.534000; val_acc: 0.506000
# (Iteration 2301 / 2450) loss: 1.424666
# (Iteration 2401 / 2450) loss: 1.335046
# (Epoch 10 / 10) train acc: 0.519000; val_acc: 0.519000
# (Iteration 1 / 4900) loss: 2.299307
# (Epoch 0 / 20) train acc: 0.174000; val_acc: 0.174000
# (Iteration 101 / 4900) loss: 1.925056
# (Iteration 201 / 4900) loss: 1.785167
# (Epoch 1 / 20) train acc: 0.384000; val_acc: 0.365000
# (Iteration 301 / 4900) loss: 1.759410
# (Iteration 401 / 4900) loss: 1.613846
# (Epoch 2 / 20) train acc: 0.427000; val_acc: 0.441000
# (Iteration 501 / 4900) loss: 1.664548
# (Iteration 601 / 4900) loss: 1.654664
# (Iteration 701 / 4900) loss: 1.610081
# (Epoch 3 / 20) train acc: 0.478000; val_acc: 0.441000
# (Iteration 801 / 4900) loss: 1.509545
# (Iteration 901 / 4900) loss: 1.514982
# (Epoch 4 / 20) train acc: 0.483000; val_acc: 0.452000
# (Iteration 1001 / 4900) loss: 1.537574
# (Iteration 1101 / 4900) loss: 1.349826
# (Iteration 1201 / 4900) loss: 1.605276
# (Epoch 5 / 20) train acc: 0.488000; val_acc: 0.478000
# (Iteration 1301 / 4900) loss: 1.499527
# (Iteration 1401 / 4900) loss: 1.539742
# (Epoch 6 / 20) train acc: 0.523000; val_acc: 0.481000
# (Iteration 1501 / 4900) loss: 1.370098
# (Iteration 1601 / 4900) loss: 1.289571
# (Iteration 1701 / 4900) loss: 1.304384
# (Epoch 7 / 20) train acc: 0.532000; val_acc: 0.482000
# (Iteration 1801 / 4900) loss: 1.299788
# (Iteration 1901 / 4900) loss: 1.391308
# (Epoch 8 / 20) train acc: 0.539000; val_acc: 0.499000
# (Iteration 2001 / 4900) loss: 1.423952
# (Iteration 2101 / 4900) loss: 1.339387
# (Iteration 2201 / 4900) loss: 1.374918
# (Epoch 9 / 20) train acc: 0.558000; val_acc: 0.500000
# (Iteration 2301 / 4900) loss: 1.307952
# (Iteration 2401 / 4900) loss: 1.416127
# (Epoch 10 / 20) train acc: 0.536000; val_acc: 0.504000
# (Iteration 2501 / 4900) loss: 1.378232
# (Iteration 2601 / 4900) loss: 1.235782
# (Epoch 11 / 20) train acc: 0.554000; val_acc: 0.504000
# (Iteration 2701 / 4900) loss: 1.326758
# (Iteration 2801 / 4900) loss: 1.181529
# (Iteration 2901 / 4900) loss: 1.370354
# (Epoch 12 / 20) train acc: 0.572000; val_acc: 0.525000
# (Iteration 3001 / 4900) loss: 1.223987
# (Iteration 3101 / 4900) loss: 1.166487
# (Epoch 13 / 20) train acc: 0.554000; val_acc: 0.525000
# (Iteration 3201 / 4900) loss: 1.293691
# (Iteration 3301 / 4900) loss: 1.202075
# (Iteration 3401 / 4900) loss: 1.250517
# (Epoch 14 / 20) train acc: 0.548000; val_acc: 0.520000
# (Iteration 3501 / 4900) loss: 1.069349
# (Iteration 3601 / 4900) loss: 1.206083
# (Epoch 15 / 20) train acc: 0.584000; val_acc: 0.511000
# (Iteration 3701 / 4900) loss: 1.299019
# (Iteration 3801 / 4900) loss: 1.197244
# (Iteration 3901 / 4900) loss: 1.033506
# (Epoch 16 / 20) train acc: 0.576000; val_acc: 0.520000
# (Iteration 4001 / 4900) loss: 1.212089
# (Iteration 4101 / 4900) loss: 1.087106
# (Epoch 17 / 20) train acc: 0.584000; val_acc: 0.530000
# (Iteration 4201 / 4900) loss: 1.311571
# (Iteration 4301 / 4900) loss: 1.094000
# (Iteration 4401 / 4900) loss: 1.186423
# (Epoch 18 / 20) train acc: 0.615000; val_acc: 0.528000
# (Iteration 4501 / 4900) loss: 1.187907
# (Iteration 4601 / 4900) loss: 1.167857
# (Epoch 19 / 20) train acc: 0.627000; val_acc: 0.527000
# (Iteration 4701 / 4900) loss: 1.108916
# (Iteration 4801 / 4900) loss: 1.103486
# (Epoch 20 / 20) train acc: 0.607000; val_acc: 0.515000
# (Iteration 1 / 1225) loss: 2.305787
# (Epoch 0 / 5) train acc: 0.093000; val_acc: 0.116000
# (Iteration 101 / 1225) loss: 1.906653
# (Iteration 201 / 1225) loss: 1.786122
# (Epoch 1 / 5) train acc: 0.345000; val_acc: 0.401000
# (Iteration 301 / 1225) loss: 1.608887
# (Iteration 401 / 1225) loss: 1.648414
# (Epoch 2 / 5) train acc: 0.437000; val_acc: 0.445000
# (Iteration 501 / 1225) loss: 1.695689
# (Iteration 601 / 1225) loss: 1.584198
# (Iteration 701 / 1225) loss: 1.556758
# (Epoch 3 / 5) train acc: 0.441000; val_acc: 0.461000
# (Iteration 801 / 1225) loss: 1.487769
# (Iteration 901 / 1225) loss: 1.352863
# (Epoch 4 / 5) train acc: 0.494000; val_acc: 0.481000
# (Iteration 1001 / 1225) loss: 1.362895
# (Iteration 1101 / 1225) loss: 1.338972
# (Iteration 1201 / 1225) loss: 1.325523
# (Epoch 5 / 5) train acc: 0.501000; val_acc: 0.477000
# (Iteration 1 / 2450) loss: 2.301989
# (Epoch 0 / 10) train acc: 0.099000; val_acc: 0.099000
# (Iteration 101 / 2450) loss: 1.978135
# (Iteration 201 / 2450) loss: 1.782968
# (Epoch 1 / 10) train acc: 0.416000; val_acc: 0.386000
# (Iteration 301 / 2450) loss: 1.737218
# (Iteration 401 / 2450) loss: 1.687509
# (Epoch 2 / 10) train acc: 0.455000; val_acc: 0.450000
# (Iteration 501 / 2450) loss: 1.540815
# (Iteration 601 / 2450) loss: 1.550108
# (Iteration 701 / 2450) loss: 1.552187
# (Epoch 3 / 10) train acc: 0.463000; val_acc: 0.466000
# (Iteration 801 / 2450) loss: 1.461607
# (Iteration 901 / 2450) loss: 1.547400
# (Epoch 4 / 10) train acc: 0.490000; val_acc: 0.470000
# (Iteration 1001 / 2450) loss: 1.429360
# (Iteration 1101 / 2450) loss: 1.324416
# (Iteration 1201 / 2450) loss: 1.420087
# (Epoch 5 / 10) train acc: 0.485000; val_acc: 0.482000
# (Iteration 1301 / 2450) loss: 1.384821
# (Iteration 1401 / 2450) loss: 1.431674
# (Epoch 6 / 10) train acc: 0.498000; val_acc: 0.470000
# (Iteration 1501 / 2450) loss: 1.495789
# (Iteration 1601 / 2450) loss: 1.232859
# (Iteration 1701 / 2450) loss: 1.298483
# (Epoch 7 / 10) train acc: 0.543000; val_acc: 0.492000
# (Iteration 1801 / 2450) loss: 1.265759
# (Iteration 1901 / 2450) loss: 1.368125
# (Epoch 8 / 10) train acc: 0.516000; val_acc: 0.492000
# (Iteration 2001 / 2450) loss: 1.310639
# (Iteration 2101 / 2450) loss: 1.153490
# (Iteration 2201 / 2450) loss: 1.245490
# (Epoch 9 / 10) train acc: 0.518000; val_acc: 0.507000
# (Iteration 2301 / 2450) loss: 1.322994
# (Iteration 2401 / 2450) loss: 1.338127
# (Epoch 10 / 10) train acc: 0.532000; val_acc: 0.508000
# (Iteration 1 / 4900) loss: 2.303483
# (Epoch 0 / 20) train acc: 0.113000; val_acc: 0.133000
# (Iteration 101 / 4900) loss: 1.874283
# (Iteration 201 / 4900) loss: 1.778394
# (Epoch 1 / 20) train acc: 0.388000; val_acc: 0.393000
# (Iteration 301 / 4900) loss: 1.752999
# (Iteration 401 / 4900) loss: 1.671330
# (Epoch 2 / 20) train acc: 0.426000; val_acc: 0.437000
# (Iteration 501 / 4900) loss: 1.584447
# (Iteration 601 / 4900) loss: 1.563327
# (Iteration 701 / 4900) loss: 1.524632
# (Epoch 3 / 20) train acc: 0.463000; val_acc: 0.467000
# (Iteration 801 / 4900) loss: 1.620232
# (Iteration 901 / 4900) loss: 1.490626
# (Epoch 4 / 20) train acc: 0.498000; val_acc: 0.472000
# (Iteration 1001 / 4900) loss: 1.477759
# (Iteration 1101 / 4900) loss: 1.483791
# (Iteration 1201 / 4900) loss: 1.479539
# (Epoch 5 / 20) train acc: 0.504000; val_acc: 0.481000
# (Iteration 1301 / 4900) loss: 1.452101
# (Iteration 1401 / 4900) loss: 1.398549
# (Epoch 6 / 20) train acc: 0.529000; val_acc: 0.493000
# (Iteration 1501 / 4900) loss: 1.478675
# (Iteration 1601 / 4900) loss: 1.324128
# (Iteration 1701 / 4900) loss: 1.256855
# (Epoch 7 / 20) train acc: 0.521000; val_acc: 0.508000
# (Iteration 1801 / 4900) loss: 1.326218
# (Iteration 1901 / 4900) loss: 1.303883
# (Epoch 8 / 20) train acc: 0.542000; val_acc: 0.500000
# (Iteration 2001 / 4900) loss: 1.234808
# (Iteration 2101 / 4900) loss: 1.255519
# (Iteration 2201 / 4900) loss: 1.315732
# (Epoch 9 / 20) train acc: 0.549000; val_acc: 0.502000
# (Iteration 2301 / 4900) loss: 1.245821
# (Iteration 2401 / 4900) loss: 1.175027
# (Epoch 10 / 20) train acc: 0.571000; val_acc: 0.508000
# (Iteration 2501 / 4900) loss: 1.264024
# (Iteration 2601 / 4900) loss: 1.314436
# (Epoch 11 / 20) train acc: 0.563000; val_acc: 0.510000
# (Iteration 2701 / 4900) loss: 1.281416
# (Iteration 2801 / 4900) loss: 1.296432
# (Iteration 2901 / 4900) loss: 1.244730
# (Epoch 12 / 20) train acc: 0.600000; val_acc: 0.527000
# (Iteration 3001 / 4900) loss: 1.199166
# (Iteration 3101 / 4900) loss: 1.215291
# (Epoch 13 / 20) train acc: 0.596000; val_acc: 0.543000
# (Iteration 3201 / 4900) loss: 1.246850
# (Iteration 3301 / 4900) loss: 1.175789
# (Iteration 3401 / 4900) loss: 1.151781
# (Epoch 14 / 20) train acc: 0.564000; val_acc: 0.533000
# (Iteration 3501 / 4900) loss: 1.223435
# (Iteration 3601 / 4900) loss: 1.191225
# (Epoch 15 / 20) train acc: 0.610000; val_acc: 0.537000
# (Iteration 3701 / 4900) loss: 1.081398
# (Iteration 3801 / 4900) loss: 1.181724
# (Iteration 3901 / 4900) loss: 1.142556
# (Epoch 16 / 20) train acc: 0.561000; val_acc: 0.534000
# (Iteration 4001 / 4900) loss: 1.036413
# (Iteration 4101 / 4900) loss: 1.086188
# (Epoch 17 / 20) train acc: 0.601000; val_acc: 0.532000
# (Iteration 4201 / 4900) loss: 1.249320
# (Iteration 4301 / 4900) loss: 1.255157
# (Iteration 4401 / 4900) loss: 1.155681
# (Epoch 18 / 20) train acc: 0.603000; val_acc: 0.546000
# (Iteration 4501 / 4900) loss: 1.066945
# (Iteration 4601 / 4900) loss: 1.106742
# (Epoch 19 / 20) train acc: 0.604000; val_acc: 0.534000
# (Iteration 4701 / 4900) loss: 1.167884
# (Iteration 4801 / 4900) loss: 1.149840
# (Epoch 20 / 20) train acc: 0.610000; val_acc: 0.549000
# lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.619796 val accuracy: 0.549000
# best validation accuracy achieved during cross-validation: 0.549000
# best_hidden_size: 1.500000e+02
# best_training_epoch: 2.000000e+01

# %% [markdown]
# best model: lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.619796 val accuracy: 0.549000
# best validation accuracy achieved during cross-validation: 0.549000
# best_hidden_size: 1.500000e+02
# best_training_epoch: 2.000000e+01

# %% [markdown]
# # Test your model!
# Run your best model on the validation and test sets. You should achieve above 48% accuracy on the validation set and the test set.

# %%
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
# Out:
# Validation set accuracy:  0.549

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Test set accuracy:  0.541

# %%
# Save best model
best_model.save("best_two_layer_net.npy")
# Out:
# best_two_layer_net.npy saved.

# %% [markdown]
# ## Inline Question 2:
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$ 1. 2.
#
# $\color{blue}{\textit Your Explanation:}$1. the more data the merrier. the model can learn a better representation.
# 2. makes the model larger, have move cabability to learn complex representations.
#
# 3 is false. we tried to increase reg value. did not work.
